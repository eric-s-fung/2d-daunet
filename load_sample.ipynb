# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np
import nibabel as nib

# %%
img = nib.load("C:/users/fungs/bmen501/data/Train/Image/CC0008_philips_15_60_F.nii.gz").get_fdata()
plt.figure()
plt.imshow(img[:,:,100])
plt.show()
print(img.shape)
# Out:
# (150, 288, 288)

# %%
img = nib.load("C:/users/fungs/bmen501/data/train/image/TUM20-20180205.nii.gz").get_fdata()
plt.figure()
plt.imshow(img[:,250,:])
plt.show()
